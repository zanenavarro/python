# %%
# Testing AWS callback script
from testing import *

from main import lambda_handler
from main import command_handler
from discord_lib import interaction_example

event_body = {}
event_body["body"] = json.dumps(interaction_example)

print(json.dumps(lambda_handler(event_body),indent=4))
# Out:
# ...
# {
#     "statusCode": 200,
#     "body": {
#         "type": 2,
#         "data": {
#             "tts": false,
#             "content": "",
#             "embeds": [
#                 {
#                     "title": "Cannellini Bean and Asparagus Salad with Mushrooms",
#                     "type": "",
# ...
